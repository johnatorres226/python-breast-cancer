# %%
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Could not find platform independent libraries <prefix>
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: c:\Users\John\Documents\Capstone Projects\Python Capstones\python-breast-cancer\venv\Scripts\python.exe -m pip install --upgrade pip
# Traceback (most recent call last):
#   File "c:\Users\John\Documents\Capstone Projects\Python Capstones\python-breast-cancer\venv\Lib\site-packages\pip\_internal\utils\temp_dir.py", line 45, in global_tempdir_manager
#     yield
#   File "C:\Users\John\AppData\Local\Programs\Python\Python312\Lib\contextlib.py", line 595, in __exit__
#     if cb(*exc_details):
#        ^^^^^^^^^^^^^^^^
#   File "C:\Users\John\AppData\Local\Programs\Python\Python312\Lib\contextlib.py", line 144, in __exit__
#     next(self.gen)
# ...

# %%
# %pip install statsmodels
# Out:
# ...
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB 330.3 kB/s eta 0:00:30
#    ---------------------------------------- 0.1/9.8 MB 656.4 kB/s eta 0:00:15
#    - -------------------------------------- 0.3/9.8 MB 2.6 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/9.8 MB 7.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.0/9.8 MB 18.4 MB/s eta 0:00:01
#    ------------------------------------ --- 9.1/9.8 MB 34.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 34.9 MB/s eta 0:00:00
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# Could not find platform independent libraries <prefix>
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# ...
